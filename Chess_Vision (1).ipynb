# %%
# %matplotlib inline

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torchvision.models as models
from torch.utils.data import Dataset
import os
import pandas as pd
from skimage import io
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
black_square = {"empty" : 0,
                  "black_pawn" : 1,
                  "black_rook" : 2,
                  "black_knight" : 3,
                  "black_bishop" : 4,
                  "black_queen" : 5,
                  "black_king" : 6,
                  "white_pawn" : 7,
                  "white_rook" : 8,
                  "white_knight" : 9,
                  "white_bishop" : 10,
                  "white_queen" : 11,
                  "white_king" : 12}
white_square = {"empty" : 13,
                  "black_pawn" : 14,
                  "black_rook" : 15,
                  "black_knight" : 16,
                  "black_bishop" : 17,
                  "black_queen" : 18,
                  "black_king" : 19,
                  "white_pawn" : 20,
                  "white_rook" : 21,
                  "white_knight" : 22,
                  "white_bishop" : 23,
                  "white_queen" : 24,
                  "white_king" : 25}
# A method to create a csv file containing the labels for each image               
def create_csv(root_dir):
  data = {}
  for subdir, dirs, files in os.walk(root_dir):
    for file in files:
      filepath = subdir + os.sep + file
      if file.endswith(".jpg"):
        path = filepath.split("/")
        if ("black_square" in filepath):
          data[filepath] = black_square[path[6]]
        elif ("white_square" in filepath):
          data[filepath] = white_square[path[6]]
  print(data)
  df = pd.DataFrame.from_dict(data, orient='index')
  df.to_csv(path_or_buf='/tmp/chess_pieces.csv')

# %%
create_csv('/tmp/ChessDiagramRecognition-master/datasets/squares')
# Out:
# {'/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square1545.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square1803.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square5064.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square4039.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square4935.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square1232.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square4813.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square5763.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square4170.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square841.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square5319.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square71.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square2441.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square134.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square3093.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square2122.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square2249.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square5703.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square6279.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square3720.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square17.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square3272.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square3400.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square1987.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square4103.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square5591.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square5127.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square4488.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square1864.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square1475.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square3015.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square2695.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square5450.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square2953.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square1614.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square2888.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square5836.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square5507.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square4872.jpg': 4, '/tmp/ChessDiagramRecognition-master/datasets/squares/black_square/black_bishop/square5001.jpg': 4, '/tmp ...

# %%
from PIL import Image
class ChessPieces(Dataset):
  def __init__(self, csv_file, root_dir, transform=None):
    self.annotations = pd.read_csv(csv_file)
    self.root_dir = root_dir
    self.transform = transform

  def __len__(self):
      return len(self.annotations)

  def __getitem__(self, index):
      img_path = os.path.join(self.root_dir, self.annotations.iloc[index, 0])
      image = Image.open(img_path)
      image = image.convert("L")
      y_label = torch.tensor(int(self.annotations.iloc[index, 1]))

      if self.transform:
        image = self.transform(image)

      return (image, y_label)

# %%
def get_piece_data():
  dataset = ChessPieces('/tmp/chess_pieces.csv', root_dir="",
                        transform=transforms.ToTensor())
  trainset, testset = torch.utils.data.random_split(dataset, [5600, 800])

  trainloader = torch.utils.data.DataLoader(trainset, batch_size=32, shuffle=True,
                                            num_workers=2)
  testloader = torch.utils.data.DataLoader(testset, batch_size=32, shuffle=False,
                                           num_workers=2)
  classes = range(25)
  return {"train": trainloader, "test": testloader, "classes": classes}
data = get_piece_data()
print(data['train'].__dict__)
# Out:
# {'dataset': <torch.utils.data.dataset.Subset object at 0x7f358b55a710>, 'num_workers': 2, 'prefetch_factor': 2, 'pin_memory': False, 'timeout': 0, 'worker_init_fn': None, '_DataLoader__multiprocessing_context': None, '_dataset_kind': 0, 'batch_size': 32, 'drop_last': False, 'sampler': <torch.utils.data.sampler.RandomSampler object at 0x7f358b55a7d0>, 'batch_sampler': <torch.utils.data.sampler.BatchSampler object at 0x7f358b55a190>, 'generator': None, 'collate_fn': <function default_collate at 0x7f35a7ab4d40>, 'persistent_workers': False, '_DataLoader__initialized': True, '_IterableDataset_len_called': None, '_iterator': None}

# %%
dataiter = iter(data['train'])
images, labels = dataiter.next()
print(images.size())
# Out:
# torch.Size([32, 1, 32, 32])

# %%
import matplotlib.pyplot as plt
import numpy as np

def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print("Labels:" + ' '.join('%9s' % data['classes'][labels[j]] for j in range(8)))


flat = torch.flatten(images, 1)
print(images.size())
print(flat.size())
# Out:
# Labels:       13         0        13         7        14        15         0        13
# torch.Size([32, 1, 32, 32])
# torch.Size([32, 1024])

# %%
import torch.nn as nn
import torch.nn.functional as F


class SimpleNet(nn.Module):
    def __init__(self, inputs=1024, hidden=512, outputs=26):
        super(SimpleNet, self).__init__()
        self.fc1 = nn.Linear(inputs, hidden)
        self.fc2 = nn.Linear(hidden, outputs)

    def forward(self, x):
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x)  # activaction function: 92.4% -> 98.6% accuracy
        x = self.fc2(x)
        # No softmax, happens in loss function
        return x

# %%
import torch.optim as optim

def train(net, dataloader, epochs=1, lr=0.01, momentum=0.9, decay=0.01, verbose=1):
  net.to(device)
  losses = []
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.SGD(net.parameters(), lr=lr, momentum=momentum, weight_decay=decay)
  for epoch in range(epochs):
    sum_loss = 0.0
    for i, batch in enumerate(dataloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = batch[0].to(device), batch[1].to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize 
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()  # autograd magic, computes all the partial derivatives
        optimizer.step() # takes a step in gradient direction

        # print statistics
        losses.append(loss.item())
        sum_loss += loss.item()
        if i % 100 == 99:    # print every 100 mini-batches
            if verbose:
              print('[%d, %5d] loss: %.3f' %
                  (epoch + 1, i + 1, sum_loss / 100))
            sum_loss = 0.0
  return losses

# %%
def accuracy(net, dataloader):
  correct = 0
  total = 0
  with torch.no_grad():
      for batch in dataloader:
          images, labels = batch[0].to(device), batch[1].to(device)
          outputs = net(images)
          _, predicted = torch.max(outputs.data, 1)
          total += labels.size(0)
          correct += (predicted == labels).sum().item()
  return correct/total

# %%
net1 = SimpleNet()

losses1 = train(net1, data['train'], epochs=25)
#torch.save(net1.state_dict(), "/tmp/SimpleNet1.pth")
plt.plot(losses1)
print("Current training accuracy: %f" % accuracy(net1, data['train']))
print("Current testing  accuracy: %f" % accuracy(net1, data['test']))
# Out:
# [1,   100] loss: 1.610
# [2,   100] loss: 0.794
# [3,   100] loss: 0.561
# [4,   100] loss: 0.429
# [5,   100] loss: 0.364
# [6,   100] loss: 0.371
# [7,   100] loss: 0.338
# [8,   100] loss: 0.334
# [9,   100] loss: 0.298
# [10,   100] loss: 0.316
# [11,   100] loss: 0.319
# [12,   100] loss: 0.324
# [13,   100] loss: 0.336
# [14,   100] loss: 0.316
# [15,   100] loss: 0.289
# [16,   100] loss: 0.273
# [17,   100] loss: 0.300
# [18,   100] loss: 0.300
# [19,   100] loss: 0.301
# [20,   100] loss: 0.280
# [21,   100] loss: 0.276
# [22,   100] loss: 0.276
# [23,   100] loss: 0.292
# [24,   100] loss: 0.273
# [25,   100] loss: 0.382
# Current training accuracy: 0.955357
# Current testing  accuracy: 0.943750

# %%
eval_pieces = {
    0: "e",
    1: "p",
    2: "r",
    3: "n",
    4: "b",
    5: "q",
    6: "k",
    7: "P",
    8: "R",
    9: "N",
    10: "B",
    11: "Q",
    12: "K",
}
class DiagramProcessor:
  def __init__(self, diagram_path):
    self.model = SimpleNet()
    self.model.load_state_dict(torch.load("/tmp/SimpleNet1.pth"))
    self.model.eval()
    self.diagram = Image.open(diagram_path)
    self.diagram = self.diagram.convert("L")
    self.diagram = self.diagram.resize((256, 256))
    self.FEN = []
    self.evals = []

  def process(self):
    squares = []
    h_step = round(self.diagram.height / 8)
    w_step = round(self.diagram.width / 8)
    array = np.asarray(self.diagram)
    for i in range(8):
      for j in range(8):
        a = i*h_step
        b = (i+1)*h_step
        c = j*w_step
        d = (j+1)*w_step
        squares.append(array[a:b,c:d])
    for square in squares:
      newsq = square[0:32,0:32]
      newsq = torchvision.transforms.functional.to_tensor(newsq)
      y_prob = self.model(newsq)
      y_classes = y_prob.argmax(axis=-1)
      y_classes = y_classes.item()
      self.evals.append(y_classes)
    
  def write_evals(self):
    return self.evals

  def writeFEN(self):
    for eval in self.evals:
      self.FEN.append(eval_pieces[eval % 13])
    empty = 0
    count = 0
    string = ""
    for letter in self.FEN:
      if count is 8:
        if empty > 0:
          string += str(empty)
        string += "/"
        empty = 0
        count = 0
      if letter is "e":
        empty = empty + 1
        if empty is 8:
          string += str(8)
          empty = 0
        count += 1
      else:
        if empty > 0:
          string += str(empty)
          string += letter
          empty = 0
          count += 1
        else:
          string += letter
          count += 1
    if empty > 0:
      string += str(empty)
    string += " w - - 0 1"
    return string

# %%
def image_selector(root_dir):
  images = []
  for subdir, dirs, files in os.walk(root_dir):
    for file in files:
      if file.endswith(".jpg"):
        image = Image.open(root_dir + file)
        images.append(file)
  return images

# %%
for file in image_selector("/tmp/ChessDiagramRecognition-master/datasets/diagrams/"):
  dp = DiagramProcessor("/tmp/ChessDiagramRecognition-master/datasets/diagrams/" + file)
  dp.process()
  print(file)
  print(dp.writeFEN())
# Out:
# d51.jpg
# 3q4/4Pppk/1bp3p1/4p1n1/2B1P2p/P4P1P/PP2PPP1/8 w - - 0 1
# d27.jpg
# 1r1q1rk1/p4ppp/b2b4/n1p5/4Q3/1PP2N2/P5R1/RNB3R1 w - - 0 1
# d86.jpg
# r2qrbk1/pb1n1p1p/1p1ppnp1/8/N1PP1B2/P2B1N1P/1P3PP1/2RqR1K1 w - - 0 1
# d77.jpg
# 2r3k1/Pq3p1p/p2qp1pP/6P1/2P2P1P/5PP1/P3P1pP/3R4 w - - 0 1
# d14.jpg
# r2q1rk1/1pp1b1pp/4bp2/pP1np3/3n4/P1NP2P1/3PPPB1/1RBR1RB1 w - - 0 1
# d30.jpg
# 4r2P/pppqnrk1/2n2P1p/3p2pP/P2P1pP1/B1PP1qP1/4RPP1/R5K1 w - - 0 1
# d46.jpg
# 1k6/1p4pp/q3p3/1q1pP3/3P1PP1/b3P3/P2r1P1P/KR6 w - - 0 1
# d19.jpg
# r1b2bk1/1pq3pp/p2pp3/4n1PB/3QP3/2N1B3/PPP4P/5RP1 w - - 0 1
# d39.jpg
# 3q1r1q/2rn1ppp/p3p3/1p1pP1pp/3P4/2Nq1P2/PP1p1P1P/1K1R3R w - - 0 1
# d100.jpg
# 8/8/1p2K3/1P1Q4/3q4/8/8/4R1P1 w - - 0 1
# d22.jpg
# r3k2r/p2b1p2/2p1p1p1/2qpP2n/8/2N2Q2/P1P2P2/1R1R4 w - - 0 1
# d58.jpg
# 2rq1rk1/PpP1ppbp/1P1p1np1/3P1PB1/2P5/1P1B4/6PP/5R2 w - - 0 1
# d89.jpg
# 3pkpk1/p3p1pp/bp2n3/2ppPp2/8/8/P2P2B1/1B1R2B1 w - - 0 1
# d31.jpg
# r6r/pbq1kp1p/np2pp2/b1p5/2P5/P1N2NP1/1PQ1PPB1/3RP3 w - - 0 1
# d32.jpg
# 2rq1rk1/pb2bppp/1p2pn2/3nN1B1/2BP4/2NR4/PP2QPPP/5RP1 w - - 0 1
# d7.jpg
# 3r1k2/ppr2pp1/q1nNp2p/4P2P/6P1/P7/5P2/3RR1K1 w - - 0 1
# d20.jpg
# r5k1/1b3ppp/1p6/2qp4/3P4/1P2PB2/5PPP/3Q2P1 w - - 0 1
# d54.jpg
# r3r1k1/pp3ppp/1bq5/7p/3pb3/PP1P4/1PP2PPP/8 w - - 0 1
# d17.jpg
# 2rr1bk1/1b1n1ppp/1p1ppn2/8/1PPNPP2/2NB4/3BR1PP/5R1P w - - 0 1
# d18.jpg
# 2rr2k1/p3bpp1/4p2p/1p6/q1nPP2P/P2R1BP1/5P2/1QB3R1 w - - 0 1
# d45.jpg
# 5RNn/Rb2R1n1/1p2P3/3n1q2/7P/P7/2P4P/4P1RP w - - 0 1
# d25.jpg
# 4rr1k/8/2p2p2/2Pq1Pbp/3P2p1/3Q1pPP/5P2/3R1BR1 w - - 0 1
# d41.jpg
# 2q4k/5Pp1/4B2p/p1p5/1P6/6PP/P4P1P/8 w - - 0 1
# d43.jpg
# 2r1r1k1/P1pq1ppp/q1pp1np1/8/4P3/8/PPP2PPP/R1B2Rn1 w - - 0 1
# d65.jpg
# r1q2rk1/pp2p2p/3pbpp1/8/2PQPP1P/1P6/PP1P2P1/8 w - - 0 1
# d63.jpg
# 5r1k/pp5p/3N2R1/4q3/2PP4/P6P/1P3r2/1K6 w - - 0 1
# d90.jpg
# r1b3kk/p1p3r1/3p1n1b/PP1Pp1pp/R3Pp1p/2N2P1P/4B1P1/3QBR2 w - - 0 1
# d4.jpg
# 4r1k1/pb1nq2p/2ppp3/6pP/2P1P1B1/2N5/PP4P1/2K2R2 w - - 0 1
# d10.jpg
# 5rk1/1b2qppp/pp2p3/4n3/1P1NP3/P1r2P2/3R2P1/R4BR1 w - - 0 1
# d3.jpg
# 7P/P1p1P1PP/1P6/Pp2P3/1P3P2/2P5/8/3P1b1P w - - 0 1
# d95.jpg
# 3r2r1/k1pq4/np1n1p2/p1pPp1pp/P3P1P1/2P2P2/2Q1K3/1R5R w - - 0 1
# d55.jpg
# 6P1/pb4p1/1p2p2P/2b2p2/2P1n3/1P1B1P1P/R7/5R2 w - - 0 1
# d52.jpg
# r1N4k/5ppp/p4n2/bpQ5/8/B3P1P1/q4PKP/8 w - - 0 1
# d28.jpg
# 5qk1/1R3ppp/2Q5/8/1p6/1P4P1/r4PPP/8 w - - 0 1
# d2.jpg
# 8/P1b1kkB1/1PpP1P2/P2pP1p1/1r1P4/3P4/8/6P1 w - - 0 1
# d68.jpg
# 3r1rnk/1p4b1/1Nbp3p/Q3pPpq/2P1Pn2/1P2B3/P2N1P2/1K1R1BR1 w - - 0 1
# d88.jpg
# 1r1k1b1P/p1p1n1p1/1pp1q2p/4N3/3PN3/8/PPP2PPP/R1B3K1 w - - 0 1
# d81.jpg
# 8/P5pk/PP1b4/4kp2/P3p3/4P3/5PPP/1R6 w - - 0 1
# d21.jpg
# r4rk1/pp3pp1/3R3p/q7/2B1P1bP/2N3n1/PPP3P1/2P5 w - - 0 1
# d72.jpg
# 6rk/pp5p/2qN2nP/8/2PR4/7P/PP3r2/2K5 w - - 0 1
# d56.jpg
# 7r/1n1bbpkq/p2p1np1/2pPp3/1pP1P1P1/1P3PBr/P1B1q1KP/3N2RR w - - 0 1
# d50.jpg
# k4rk1/ppP1pppp/1p2pn1P/P5P1/1P1PPP1P/P2B1N2/PB1P1PPP/2R1B1b1 w - - 0 1
# d83.jpg
# r4rk1/1b2bp2/p4n1p/3q2p1/2Rp4/3n1PBN/PP2N1PP/3Q1RK1 w - - 0 1
# d97.jpg
# 1k1r3P/ppqb4/5Ppp/3p4/P2np3/3BR1P1/2PB1PPP/R5K1 w - - 0 1
# d62.jpg
# 6P1/pb4p1/1p2p2P/2b2p2/2P1n1P1/1P1B4/R4PR1/8 w - - 0 1
# d38.jpg
# r6P/1pp3k1/1b6/p2P1p2/P1N1pn2/2P2PP1/PP5P/4RR2 w - - 0 1
# d53.jpg
# r1q2rk1/pp2p2p/3pbpp1/8/2PQPP1P/1P6/PP1P2P1/8 w - - 0 1
# d24.jpg
# 2rq1rk1/1b3pbp/ppn1p1p1/2pn4/2B2P2/P1NPPN2/1PQB2PP/3R1RR1 w - - 0 1
# d16.jpg
# 2r3k1/p4ppp/8/3p4/b7/P4NPk/1P2PP1P/4P3 w - - 0 1
# d73.jpg
# r2r3k/1p4b1/2bp1n1p/3NpPpk/1qP1Pn2/1P2B3/P2N1P2/1K2RBR1 w - - 0 1
# d15.jpg
# r2q1rk1/pp3ppp/1bpN1n2/4n3/1PP1P1p1/P1N2PP1/6BP/R1BRB2K w - - 0 1
# d59.jpg
# 3r1rnk/1p4b1/1Nbp3p/q3pPpq/2P1Pn2/1P2BP2/P2N4/1K1R1BR1 w - - 0 1
# d44.jpg
# 2q3rk/3n3p/1pBp1n1p/pPpPpPpP/P3P3/P1Pn4/1P1P1P2/7R w - - 0 1
